# %%
import sympy as sp
from sympy import latex
from sympy.physics.mechanics import dynamicsymbols

import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d

import copernicusmarine
from scipy.integrate import cumulative_trapezoid as cumtrapz

import xarray as xr

# %%
t = dynamicsymbols._t


x, y, z, theta, phi = dynamicsymbols("x y z theta phi")  # x and y -> buoy coordinates

m_b, m_d, l, g = sp.symbols(
    "m_b m_d l g", positive=True
)  # mass buoy, mass drogue in [kg], wire length in [m], g in [m(s^2)]

k_b, k_d = sp.symbols("k_b k_d", positive=True)  # drag coefficients for buoy and drogue

U_b, V_b, U_d, V_d = sp.symbols(
    "U_b V_b U_d V_d", real=True
)  # surface horizontal velocities

# U_0, V_0 = sp.symbols('U_0 V_0', real = True) # surface horizontal velocities

# %% [markdown]
# The buoy is fixed to the water surface and initially has no possibility of lifting off or being pushed/pulled underwater (z = 0). The position of the drogue is described in spherical coordinates depending on the position of the buoy.

# %%
r_b = sp.Matrix([x, y, 0])  # buoy position

r = l * sp.Matrix(
    [
        sp.sin(theta) * sp.cos(phi),
        sp.sin(theta) * sp.sin(phi),
        sp.cos(theta),
    ]
)

r_d = r_b + r  # drogue position

display(r_d)
# Out:
# Matrix([
# [l*sin(theta(t))*cos(phi(t)) + x(t)],
# [l*sin(phi(t))*sin(theta(t)) + y(t)],
# [                   l*cos(theta(t))]])

# %% [markdown]
# u_b and u_d represent the flow velocities at the water surface and at the height of the drogue. Later, the flow velocity below the water surface will be implemented as a function of z.

# %%
# velocities

v_b = r_b.diff(t)
v_d = r_d.diff(t)

u_b = sp.Matrix([U_b, V_b, 0])
u_d = sp.Matrix([U_d, V_d, 0])

# %% [markdown]
# F_b and F_d describe the drag forces on the buoy and the drogue.

# %%
def _mag(vec):
    return sp.sqrt(vec.dot(vec))


F_b = -k_b * _mag(v_b - u_b) * (v_b - u_b)  # drag buoy with ext. velocity
F_d = -k_d * _mag(v_d - u_d) * (v_d - u_d)  # drag drogue with ext. velocity

# %%
# lagrangian

T = sp.Rational(1, 2) * m_b * v_b.dot(v_b) + sp.Rational(1, 2) * m_d * v_d.dot(
    v_d
)  # kinetic energy

V = m_d * g * r_d[2]  # potential energy

L = T - V  # lagrangian

# %% [markdown]
# Defining $q$, $\dot{q}$ and $\ddot{q}$

# %%
q = sp.Matrix([x, y, theta, phi])
qd = q.diff(t)
qdd = qd.diff(t)

# %% [markdown]
# Generalized forces: $\left(\begin{array}{c}
#         \frac{\partial r}{\partial \theta} \cdot F \\
#         \frac{\partial r}{\partial \phi} \cdot F
#         \end{array}\right)$

# %%
Q = sp.Matrix([r_b.diff(qi).dot(F_b) + r_d.diff(qi).dot(F_d) for qi in q])

Q = sp.simplify(Q)

# %% [markdown]
# Equations of motion:
#
# $\frac{\partial}{\partial t} (\frac{\partial L}{\partial \dot{q}_j}) - \frac{\partial L}{\partial q_j} - Q_j = 0$

# %%
eoms = sp.Matrix(
    [L.diff(qdj).diff(t) - L.diff(qj) - Qj for qj, qdj, Qj in zip(q, qd, Q)]
)
eoms = sp.simplify(eoms)

# %%
M, F = sp.linear_eq_to_matrix(eoms, list(qdd))

# %%
Ux, Uy = sp.symbols('Ux Uy', real = True)
subst = {
    x.diff(t): Ux,
    y.diff(t): Uy,
    
    theta.diff(t): 0,
    phi.diff(t): 0,

    x.diff(t, 2): 0,
    y.diff(t, 2): 0,
    theta.diff(t, 2): 0,
    phi.diff(t, 2): 0,  
}
eoms_steady_state = sp.simplify(eoms.subs(subst))
display(eoms_steady_state)
# Out:
# Matrix([
# [                                              -k_b*(U_b - Ux)*sqrt((U_b - Ux)**2 + (Uy - V_b)**2) - k_d*(U_d - Ux)*sqrt((U_d - Ux)**2 + (Uy - V_d)**2)],
# [                                               k_b*(Uy - V_b)*sqrt((U_b - Ux)**2 + (Uy - V_b)**2) + k_d*(Uy - V_d)*sqrt((U_d - Ux)**2 + (Uy - V_d)**2)],
# [-l*(g*m_d*sin(theta(t)) + k_d*sqrt((U_d - Ux)**2 + (Uy - V_d)**2)*(U_d*cos(phi(t)) - Ux*cos(phi(t)) - Uy*sin(phi(t)) + V_d*sin(phi(t)))*cos(theta(t)))],
# [                         k_d*l*sqrt((U_d - Ux)**2 + (Uy - V_d)**2)*(U_d*sin(phi(t)) - Ux*sin(phi(t)) + Uy*cos(phi(t)) - V_d*cos(phi(t)))*sin(theta(t))]])

# %%
parameter = {
    k_b: 3.0,
    k_d: 2.0,
    U_b: 1.0, V_b: 1.5,
    U_d: 2.0, V_d: -0.5,
    g: 9.81,
    l: 3.0,
    m_d: 1.0,
}

th, ph = sp.symbols('th ph', real = True)

equations_with_params = eoms_steady_state.subs(parameter).subs({theta:th, phi:ph})

# %%
equations = list(equations_with_params)
sol = sp.nsolve(equations, (Ux, Uy, th, ph), (0.0, 0.0, 0.2, 1.0))
sol
# Out:
# Matrix([
# [    1.44948974278318],
# [   0.601020514433644],
# [3.34882109737048e-27],
# [   0.463647609000806]])

# %%
eqs = list(eoms_steady_state.subs({theta:th, phi:ph}))
sol_a = sp.solve(eqs, (Ux, Uy, th, ph))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 eqs = list(eoms_steady_state.subs({theta:th, phi:ph}))
# ----> 2 sol_a = sp.solve(eqs, (Ux, Uy, th, ph))
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/solvers/solvers.py:1170, in solve(f, *symbols, **flags)
#    1168         solution = _solve(f[0], *symbols, **flags)
#    1169 else:
# -> 1170     linear, solution = _solve_system(f, symbols, **flags)
#    1171 assert type(solution) is list
#    1172 assert not solution or type(solution[0]) is dict, solution
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/solvers/solvers.py:1963, in _solve_system(exprs, symbols, **flags)
#    1961 for s in ok_syms:
#    1962     try:
# -> 1963         soln = _vsolve(eq2, s, **flags)
#    1964     except NotImplementedError:
#    1965         continue
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/solvers/solvers.py:2638, in _vsolve(e, s, **flags)
#    2636 def _vsolve(e, s, **flags):
#    2637     """return list of scalar values for the solution of e for symbol s"""
# -> 2638     return [i[s] for i in _solve(e, s, **flags)]
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/solvers/solvers.py:1744, in _solve(f, *symbols, **flags)
#    1738     result = [r for r in result if
#    1739               not any(checksol(d, r, **flags)
#    1740                       for d in dens)]
#    1741 if check:
#    1742     # keep only results if the check is not False
#    1743     result = [r for r in result if
# -> 1744               checksol(f_num, r, **flags) is not False]
#    1745 return result
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/solvers/solvers.py:295, in checksol(f, symbol, sol, **flags)
#     293         # there are free symbols -- simple expansion might work
#     294         _, val = val.as_content_primitive()
# --> 295         val = _mexpand(val.as_numer_denom()[0], recursive=True)
#     296 elif attempt == 2:
#     297     if minimal:
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/function.py:2857, in _mexpand(expr, recursive)
#    2855 was = None
#    2856 while was != expr:
# -> 2857     was, expr = expr, expand_mul(expand_multinomial(expr))
#    2858     if not recursive:
#    2859         break
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/function.py:2898, in expand_multinomial(expr, deep)
#    2884 def expand_multinomial(expr, deep=True):
#    2885     """
#    2886     Wrapper around expand that only uses the multinomial hint.  See the expand
#    2887     docstring for more information.
#    (...)   2896
#    2897     """
# -> 2898     return sympify(expr).expand(deep=deep, mul=False, power_exp=False,
#    2899     power_base=False, basic=False, multinomial=True, log=False)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/expr.py:3704, in Expr.expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3702     if use_hint:
#    3703         hint = '_eval_expand_' + hint
# -> 3704         expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3706 while True:
#    3707     was = expr
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
#     [... skipping similar frames: Expr._expand_hint at line 3635 (15 times)]
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/expr.py:3643, in Expr._expand_hint(expr, hint, deep, **hints)
#    3640         expr = expr.func(*sargs)
#    3642 if hasattr(expr, hint):
# -> 3643     newexpr = getattr(expr, hint)(**hints)
#    3644     if newexpr != expr:
#    3645         return (newexpr, True)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/power.py:1106, in Pow._eval_expand_multinomial(self, **hints)
#    1103     expansion_dict = multinomial_coefficients(len(p), n)
#    1104     # in our example: {(3, 0): 1, (1, 2): 3, (0, 3): 1, (2, 1): 3}
#    1105     # and now construct the expression.
# -> 1106     return basic_from_dict(expansion_dict, *p)
#    1107 else:
#    1108     if n == 2:
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/polys/polyutils.py:405, in expr_from_dict(rep, *gens)
#     402         if m:
#     403             term.append(Pow(g, m))
# --> 405     result.append(Mul(*term))
#     407 return Add(*result)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/operations.py:108, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#     105 if len(args) == 1:
#     106     return args[0]
# --> 108 c_part, nc_part, order_symbols = cls.flatten(args)
#     109 is_commutative = not nc_part
#     110 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/mul.py:722, in Mul.flatten(cls, seq)
#     719 c_part = _new
#     721 # order commutative part canonically
# --> 722 _mulsort(c_part)
#     724 # current code expects coeff to be always in slot-0
#     725 if coeff is not S.One:
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/mul.py:36, in _mulsort(args)
#      34 def _mulsort(args):
#      35     # in-place sorting of args
# ---> 36     args.sort(key=_args_sortkey)
#
# File ~/src/2025_drogued_drifters/.pixi/envs/default/lib/python3.14/site-packages/sympy/core/basic.py:411, in Basic.compare(self, other)
#     409 if c:
#     410     return c
# --> 411 for l, r in zip(st, ot):
#     412     if isinstance(l, Basic):
#     413         c = l.compare(r)
#
# KeyboardInterrupt:
